# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.set() # Set default plotter to be seaborn

# %%
data = sns.load_dataset('planets') 
data=pd.DataFrame(data)
data = data[data["method"] == "Radial Velocity"]
data
# Out:
#               method  number  orbital_period   mass  distance  year
# 0    Radial Velocity       1        269.3000   7.10     77.40  2006
# 1    Radial Velocity       1        874.7740   2.21     56.95  2008
# 2    Radial Velocity       1        763.0000   2.60     19.84  2011
# 3    Radial Velocity       1        326.0300  19.40    110.62  2007
# 4    Radial Velocity       1        516.2200  10.50    119.47  2009
# ..               ...     ...             ...    ...       ...   ...
# 914  Radial Velocity       1          6.9580   0.34       NaN  2014
# 915  Radial Velocity       1          5.1180   0.40       NaN  2014
# 916  Radial Velocity       1        121.7100   1.54       NaN  2014
# 939  Radial Velocity       1          4.4264    NaN       NaN  2012
# 940  Radial Velocity       1          2.1451    NaN       NaN  2012
#
# [553 rows x 6 columns]

# %% [markdown]
# ### This is the relationship between the mass of planet and the Radial velocity of planets, as we show when the mass incresed the radial velocity will decrease. So the plantes that have less masses have a less radial velocity.

# %%
sns.histplot(data=data, x="mass", hue="method", multiple="stack")
# Out:
# <AxesSubplot:xlabel='mass', ylabel='Count'>

# %% [markdown]
# ## this flow chart shows the relation ship between the orbited period and distance of planets, as we show when the distance increase the orbital period decrease.

# %%
sns.histplot(data=data.head(30), x="orbital_period", hue="distance", multiple="stack")
# Out:
# <AxesSubplot:xlabel='orbital_period', ylabel='Count'>

# %% [markdown]
# ## This flow chart indicate that there is aleinar relationship between the orbital periode, when mass incresed the orbital periode will  increase

# %%
sns.regplot(x='mass', y='orbital_period', data=data, color='blue')
# Out:
# <AxesSubplot:xlabel='mass', ylabel='orbital_period'>

# %% [markdown]
# # Concolusion:
# 1. the relationship between the mass of planet and the Radial velocity of planets, as we show when the mass incresed the radial velocity will decrease. So the plantes that have less masses have a less radial velocity.
# 2. There is aleinar relationship between the orbital periode, when mass incresed the orbital periode increasese.
# 3. There is aleinar relationship between the orbital periode, when mass incresed the orbital periode will increase
